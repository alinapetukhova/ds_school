# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'

# %%
df_religion = pd.read_csv('data set/national.csv')
df_religion.head()
# Out:
#    year                     state code  christianity_protestant  \
# 0  1945  United States of America  USA                 66069671
# 1  1950  United States of America  USA                 73090083
# 2  1955  United States of America  USA                 79294628
# 3  1960  United States of America  USA                 90692928
# 4  1965  United States of America  USA                 94165803
#
#    christianity_romancatholic  christianity_easternorthodox  \
# 0                    38716742                       1121898
# 1                    42635882                       3045420
# 2                    46402368                       3454916
# 3                    50587880                       3334535
# 4                    64761783                       4792868
#
#    christianity_anglican  christianity_other  christianity_all  \
# 0                2400000             1956807         110265118
# 1                3045420             1177214         122994019
# ...

# %%
new_sample_df_usa = df_religion[df_religion['code'] == 'USA'] [['code', 'year', 'noreligion_percent']]
new_sample_df_usa.plot('year', 'noreligion_percent', kind = 'line', title = 'Percentage of non-religious population of the United States')
plt.show()

# %%
new_sample_df_usa
# Out:
#    code  year  noreligion_percent
# 0   USA  1945              0.1635
# 1   USA  1950              0.1482
# 2   USA  1955              0.1404
# 3   USA  1960              0.1193
# 4   USA  1965              0.1020
# 5   USA  1970              0.1020
# 6   USA  1975              0.1148
# 7   USA  1980              0.1177
# 8   USA  1985              0.1065
# 9   USA  1990              0.0977
# 10  USA  1995              0.1312
# 11  USA  2000              0.1600
# 12  USA  2005              0.1750
# 13  USA  2010              0.1900

# %%
new_sample_df_newz = df_religion[df_religion['code'] == 'NEW'] [['year', 'noreligion_percent']]
new_sample_df_newz.plot('year', 'noreligion_percent', kind = 'line', title = 'Percentage of non-religious population of the New Zeland')
plt.show()

# %%
new_sample_df_newz = df_religion[df_religion['code'] == 'NTH'] [['year', 'noreligion_percent']]
new_sample_df_newz.plot('year', 'noreligion_percent', kind = 'line', title = 'Percentage of non-religious population of the NTH')
plt.show()

# %%
noreligion_in_FWC_year
# Out:
#                          state  year  noreligion_percent
# 10    United States of America  1995              0.1312
# 11    United States of America  2000              0.1600
# 12    United States of America  2005              0.1750
# 13    United States of America  2010              0.1900
# 24                      Canada  1995              0.0945
# 25                      Canada  2000              0.1284
# 26                      Canada  2005              0.1269
# 27                      Canada  2010              0.1643
# 423             United Kingdom  1995              0.1177
# 424             United Kingdom  2000              0.2188
# 425             United Kingdom  2005              0.2444
# 426             United Kingdom  2010              0.2616
# 437                    Ireland  1995              0.0244
# 438                    Ireland  2000              0.0353
# 439                    Ireland  2005              0.0439
# ...

# %%
first_world_countries = ['United States of America', 'United Kingdom', 'Netherlands', 'Germany', 'Japan', 'Italy', 'Spain', 'Canada', 'Australia', 'Netherlands', 'Belgium', 'Sweden', 'Austria', 'Switzerland','Singapore','Denmark','Finland','Norway','Ireland', 'New Zealand', 'Luxembourg', 'Iceland']

noreligion_in_FWC = df_religion.loc[df_religion['state'].isin(first_world_countries), ['state', 'year', 'noreligion_percent']]

noreligion_in_FWC_year = noreligion_in_FWC[noreligion_in_FWC['year'] >= 1970] [['state', 'year', 'noreligion_percent']]

noreligion_in_FWC_year.groupby(['year'])['noreligion_percent'].mean().plot(title = 'Level of non-religiosity of the countries of the first world (country mean)')

# %%
# noreligion_in_FWC_year = noreligion_in_FWC_year.drop('1975', axis=1)
# tmp = tmp.drop('1975', axis=1)
# tmp = noreligion_in_FWC_year
# tmp['1975'] = noreligion_in_FWC_year.loc[noreligion_in_FWC_year['year'] == 1975, 'noreligion_percent']
# noreligion_in_FWC_year.loc[noreligion_in_FWC_year['year'] == 2010, ['state', 'noreligion_percent']]
# tmp = noreligion_in_FWC_year.loc[noreligion_in_FWC_year['year'] == 2010, ['state', 'noreligion_percent']]
# tmp['2010'] = noreligion_in_FWC_year.loc[noreligion_in_FWC_year['year'] == 2010, 'noreligion_percent'].asobject
# tmp = tmp.drop('noreligion_percent', axis=1)
corr_matrix = tmp.drop(['state'], axis=1).corr()
sns.heatmap(corr_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-379-55c452fe9091> in <module>
#       8 # tmp = tmp.drop('noreligion_percent', axis=1)
#       9 corr_matrix = tmp.drop(['state'], axis=1).corr()
# ---> 10 sns.heatmap(corr_matrix)
#
# c:\users\александр\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ...

# %%
noreligion_in_FWC_year.loc[noreligion_in_FWC_year['year'] == 2010, 'noreligion_percent'].asobject
# Out:
# c:\users\александр\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'asobject' is deprecated. Use 'astype(object)' instead
#   """Entry point for launching an IPython kernel.
# array([0.19, 0.1643, 0.2616, 0.0605, 0.34, 0.192, 0.0496, 0.1342, 0.16,
#        0.23, 0.1542, 0.1868, 0.166, 0.16, 0.1105, 0.1011, 0.0325, 0.095,
#        0.1178, 0.3101, 0.3919], dtype=object)

# %%
# noreligion_in_FWC_year['1975'] = noreligion_in_FWC_year.loc[noreligion_in_FWC_year['year'] == 1970, 'noreligion_percent']
# tmp = tmp.drop('noreligion_percent', axis=1)
# tmp = tmp.dropna(axis=0, how='any')
tmp['1990'] = noreligion_in_FWC_year.loc[noreligion_in_FWC_year['year'] == 1990, 'noreligion_percent'].asobject
tmp
# Out:
# c:\users\александр\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: 'asobject' is deprecated. Use 'astype(object)' instead
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-351-6f14fc117d46> in <module>
#       2 # tmp = tmp.drop('noreligion_percent', axis=1)
#       3 # tmp = tmp.dropna(axis=0, how='any')
# ----> 4 tmp['1990'] = noreligion_in_FWC_year.loc[noreligion_in_FWC_year['year'] == 1990, 'noreligion_percent'].asobject
#       5 tmp
#
# c:\users\александр\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ...

# %%
df_religion[df_religion['year'] >= 1990].groupby(['year'])['noreligion_percent'].mean()
# Out:
# year
# 1990    0.052984
# 1995    0.063650
# 2000    0.063789
# 2005    0.068052
# 2010    0.073432
# Name: noreligion_percent, dtype: float64

# %%
df_religion[df_religion['year'] >= 1990].groupby(['year'])['noreligion_percent'].mean().plot(title = 'The average percentage of non-religious population in the world')

# %%
df = pd.read_csv('data set/national.csv')
df[df['state'].apply(lambda country: country[0] == 'K')].head()
# Out:
#       year   state code  christianity_protestant  christianity_romancatholic  \
# 698   2010  Kosovo  KOS                        0                       38306
# 1140  1965   Kenya  KEN                  1392288                     1469880
# 1141  1970   Kenya  KEN                  1574580                     1911990
# 1142  1975   Kenya  KEN                  2011950                     2414340
# 1143  1980   Kenya  KEN                  2674000                     3076200
#
#       christianity_easternorthodox  christianity_anglican  christianity_other  \
# 698                          25748                      0                   0
# 1140                        168256                 387560             2250000
# 1141                        224940                 562350             2680989
# 1142                        300720                 736125             3253250
# 1143                        376500                 909900             4415500
#
# ...

# %%
numerical = list(set(df.columns) - 
                 set(['year', 'state', 'christianity_protestant', 
                      'christianity_romancatholic', 'christianity_easternorthodox', 'source_code']))

corr_matrix = df[numerical].corr()
sns.heatmap(corr_matrix)

# %%
first_world_countries = ['United States of America', 'United Kingdom', 'Netherlands', 'Germany', 'Japan', 'Italy', 'Spain', 'Canada', 'Australia', 'Netherlands', 'Belgium', 'Sweden', 'Austria', 'Switzerland','Singapore','Denmark','Finland','Norway','Ireland', 'New Zealand', 'Luxembourg', 'Iceland']

dfABR = pd.read_csv('data set/Adolescent birth rate (births per 1,000 women ages 15-19).csv', header = 1) # Коэффициент рождаемости среди подростков (число рождений на 1000 женщин в возрасте 15-19 лет)

tmp_Ser = pd.Series([])
tmp_Ser = dfABR['Country'].str.strip()
dfABR['Country'] = tmp_Ser

dfABR = dfABR.loc[dfABR['Country'].isin(first_world_countries), ['Country', '1990', '1995', '2000','2005','2010','2015']]

if dfABR.shape[0] != len(first_world_countries):
    print ('error', len(first_world_countries) - dfABR.shape[0], 'country: ')
    print (list(set(first_world_countries) - set(dfABR['Country'])))
dfABR.head()
# Out:
# error 2 country:
# ['United States of America']
#       Country  1990  1995  2000  2005  2010  2015
# 7   Australia  21.1  20.9  19.5  16.9  16.0  13.9
# 8     Austria  21.4  20.4  14.8  13.3   9.8   7.7
# 15    Belgium  11.4  10.8  10.2  10.9   8.0   5.5
# 30     Canada  23.2  25.1  20.1  14.4  12.6  10.4
# 45    Denmark   9.2   8.9   8.0   6.6   5.2   4.3

# %%
first_world_countries = ['United States of America', 'United Kingdom', 'Netherlands', 'Germany', 'Japan', 'Italy', 'Spain', 'Canada', 'Australia', 'Netherlands', 'Belgium', 'Sweden', 'Austria', 'Switzerland','Singapore','Denmark','Finland','Norway','Ireland', 'New Zealand', 'Luxembourg', 'Iceland']
dfEYS = pd.read_csv('data set/Expected years of schooling (years).csv', header = 1) # Ожидаемые годы обучения (лет)
dfEYS.dropna()
dfEYS.dropna(axis='columns',how='all', inplace=True)
dfEYS.head()
# Out:
#   HDI Rank (2017)       Country  1990  1991  1992  1993  1994  1995  1996  \
# 0             168   Afghanistan   2.6   2.9   3.2   3.6   3.9   4.2   4.6
# 1              68       Albania  11.6  11.8  10.7  10.2  10.1  10.2  10.3
# 2              85       Algeria   9.6   9.7   9.8   9.8   9.9   9.8  10.0
# 3              35       Andorra  10.8  10.8  10.8  10.8  10.8  10.8  10.8
# 4             147        Angola   3.8   3.6   3.5   3.7   3.8   3.9   4.0
#
#    1997  ...  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0   4.9  ...   9.2   9.5   9.8  10.0  10.2  10.4  10.4  10.4  10.4
# 1  10.6  ...  12.3  13.1  13.8  14.7  14.8  14.8  14.8  14.8  14.8
# 2  10.3  ...  13.6  14.0  14.3  14.3  14.3  14.3  14.3  14.3  14.4
# 3  10.8  ...  11.7  11.7  11.7  13.5  13.5  13.5  13.5  13.5  13.5
# 4   4.1  ...   9.0   8.6   9.5   9.9  10.3  10.7  11.0  11.4  11.8
#
#    Unnamed: 57
# 0            a
# 1            a
# 2            a
# 3          a,b
# 4          a,c
#
# ...

# %%
df = pd.read_csv('data set/Internet users, total (% of population).csv') #
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\александр\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-9b38ee317d13> in <module>
# ...

# %%
df_LR = pd.read_csv('data set/Literacy rate, adult (% ages 15 and older).csv', header = 1, encoding="utf_8")
df_LR.dropna(axis='columns',how='all', inplace=True)
df_LR.head()
# Out:
#    HDI Rank (2017)       Country  1990  1995  2000  2005  2010  2011  2012  \
# 0            168.0   Afghanistan   NaN   NaN   NaN   NaN   NaN  31.7   NaN
# 1             68.0       Albania   NaN   NaN   NaN   NaN   NaN  96.8  97.2
# 2             35.0       Andorra   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3            147.0        Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4             47.0     Argentina   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2013  2014   2015   2016
# 0   NaN   NaN    NaN    NaN
# 1   NaN   NaN    NaN    NaN
# 2   NaN   NaN  100.0  100.0
# 3   NaN  66.0    NaN    NaN
# 4   NaN   NaN   98.1    NaN

# %%
first_world_countries = ['United States of America', 'United Kingdom', 'Netherlands', 'Germany', 'Japan', 'Italy', 'Spain', 'Canada', 'Australia', 'Netherlands', 'Belgium', 'Sweden', 'Austria', 'Switzerland','Singapore','Denmark','Finland','Norway','Ireland', 'New Zealand', 'Luxembourg', 'Iceland']
df_LR = df_LR.loc[df_LR['Country'] == 'Albania', ['Country', '1990', '1995', '2000','2005','2010','2015']]
df_LR
# Out:
# Empty DataFrame
# Columns: [Country, 1990, 1995, 2000, 2005, 2010, 2015]
# Index: []

# %%
df_MMR = pd.read_csv('data set/Maternal mortality ratio (deaths per 100,000 live births).csv', header = 1, encoding="utf-8-sig")
df_MMR.dropna(axis='columns',how='all', inplace=True)
df_MMR.head()
# Out:
#   HDI Rank (2017)       Country    1990    1995    2000   2005   2010   2011  \
# 0             168   Afghanistan  1340.0  1270.0  1100.0  821.0  584.0  536.0
# 1              68       Albania    71.0    53.0    43.0   30.0   30.0   30.0
# 2              85       Algeria   216.0   192.0   170.0  148.0  147.0  147.0
# 3             147        Angola  1160.0  1150.0   924.0  705.0  561.0  546.0
# 4              47     Argentina    72.0    63.0    60.0   58.0   58.0   56.0
#
#     2012   2013   2014   2015
# 0  496.0  459.0  425.0  396.0
# 1   30.0   29.0   29.0   29.0
# 2  145.0  144.0  141.0  140.0
# 3  526.0  509.0  493.0  477.0
# 4   55.0   54.0   54.0   52.0

# %%
df_NMR = pd.read_csv('data set/Net migration rate (per 1,000 people).csv', header = 1, encoding="utf-8-sig")
df_MMR.dropna(axis='columns', how='all', inplace=True)
df_MMR.head()
# Out:
#   HDI Rank (2017)       Country    1990    1995    2000   2005   2010   2011  \
# 0             168   Afghanistan  1340.0  1270.0  1100.0  821.0  584.0  536.0
# 1              68       Albania    71.0    53.0    43.0   30.0   30.0   30.0
# 2              85       Algeria   216.0   192.0   170.0  148.0  147.0  147.0
# 3             147        Angola  1160.0  1150.0   924.0  705.0  561.0  546.0
# 4              47     Argentina    72.0    63.0    60.0   58.0   58.0   56.0
#
#     2012   2013   2014   2015
# 0  496.0  459.0  425.0  396.0
# 1   30.0   29.0   29.0   29.0
# 2  145.0  144.0  141.0  140.0
# 3  526.0  509.0  493.0  477.0
# 4   55.0   54.0   54.0   52.0

# %%
df_PWL = pd.read_csv('data set/Population with at least some secondary education (% ages 25 and older).csv', header = 1, encoding = "utf-8-sig")
df_PWL.dropna(axis='columns', how='all', inplace=True)
df_PWL.head()
# Out:
#   HDI Rank (2017)       Country  1990  1995  2000  2005  2010  2011  2012  \
# 0             168   Afghanistan   8.2   9.8  11.1  14.5  18.2  19.2  20.2
# 1              68       Albania  64.7  71.8  75.7  82.7  83.8  84.8  87.2
# 2              85       Algeria  16.6  23.8  31.5  24.2  28.9  30.4  31.9
# 3              35       Andorra   NaN   NaN   NaN   NaN  61.1  64.1  67.0
# 4              47     Argentina  37.3  41.7  45.9  56.4  56.9  58.3  59.7
#
#    2013  2014  2015  2016  2017 Unnamed: 25
# 0  21.2  22.2  22.2  23.2  25.1         a,b
# 1  89.2  91.2  91.7  92.3  92.9           a
# 2  33.4  34.9  34.9  36.4  37.7         a,b
# 3  69.9  72.8  72.8  72.5  72.5           a
# 4  61.1  62.4  62.4  63.8  64.8         a,b

# %%
df_UT = pd.read_csv('data set/Unemployment, total (% of labour force).csv', header = 1, encoding="utf-8-sig")
df_UT.dropna(axis='columns', how='all', inplace=True)
df_UT.head()
# Out:
#   HDI Rank (2017)       Country  1991  1995  2000  2005  2010  2011  2012  \
# 0             168   Afghanistan  12.0   8.7  11.2   8.5   7.8   8.2   7.9
# 1              68       Albania  22.3  23.9  22.7  17.5  14.2  14.0  13.4
# 2              85       Algeria  20.6  27.9  29.8  15.3  10.0  10.0  11.0
# 3             147        Angola  23.7  23.9  23.7  21.4   9.9   7.4   7.4
# 4              47     Argentina   5.6  18.8  15.0  11.5   7.4   7.1   7.3
#
#    2013  2014  2015  2016  2017 Unnamed: 25
# 0   8.5   8.7   8.9   8.8   8.8           a
# 1  15.6  17.5  17.1  15.2  13.9           a
# 2   9.8  10.6  11.2  10.2  10.0           a
# 3   7.3   7.3   7.3   7.7   8.2           a
# 4   6.6   7.0   6.9   8.4   8.7           a

# %%
df_UY = pd.read_csv('data set/Unemployment, youth (% ages 15–24).csv', header = 1, encoding='utf-8')
df_UY.dropna(axis='columns', how='all', inplace=True)
df_UY.head()
# Out:
#   HDI Rank (2017)       Country  1991  1995  2000  2005  2010  2011  2012  \
# 0             168   Afghanistan  25.6  17.8  23.6  17.3  16.5  17.3  16.6
# 1              68       Albania  31.1  36.3  35.6  31.1  29.2  28.8  27.7
# 2              85       Algeria  38.8  51.2  52.0  30.7  22.0  22.5  27.6
# 3             147        Angola  54.5  55.2  54.6  49.9  22.8  16.9  17.0
# 4              47     Argentina  14.8  47.8  38.4  26.0  18.7  18.5  18.5
#
#    2013  2014  2015  2016  2017 Unnamed: 25
# 0  17.5  17.9  18.1  17.9  17.7           a
# 1  30.5  39.4  40.1  32.7  30.0           a
# 2  25.1  25.8  29.9  24.0  23.9           a
# 3  17.0  17.0  16.9  18.0  19.1           a
# 4  19.4  18.3  19.5  23.0  24.7           a
